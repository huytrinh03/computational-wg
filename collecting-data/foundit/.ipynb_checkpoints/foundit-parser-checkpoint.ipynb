# %% [markdown]
# # Creating the URLs from job posting information

# %%
import pandas as pd
import re

# Function to replace spaces and punctuation with hyphens
def replace_with_hyphen(text):
    return re.sub(r'[\s\W]+', '-', text)

def get_job_url(csv_file_path):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file_path)
    
    # Process each column and store the edited data in new columns
    df['edited_job-title'] = df['job-title'].apply(replace_with_hyphen)
    df['edited_company'] = df['company'].apply(replace_with_hyphen)
    df['edited_locations'] = df['locations'].apply(replace_with_hyphen)
    df['edited_job-id'] = (df['job-id']).astype(str)
    
    # Add a new column 'job-url'
    df['job-url'] = 'https://foundit.in/job/' + df['edited_job-title'] + "-" + df['edited_company'] + "-" + df['edited_locations'] + "-" + df['edited_job-id']
    
    # Display the DataFrame
    return df

# %%
df = get_job_url("foundit-IT.csv")

# %%
job_url = df['job-url']

# %% [markdown]
# # Scrape job posting information from URLs

# %%
import pandas as pd
import requests
import time
from bs4 import BeautifulSoup
from fake_useragent import UserAgent

# Create a fake user agent
ua = UserAgent()

# Create a request header containing the fake user agent
request_headers = {
    'user-agent': userAgent
}

# Function to scrape job information from a URL
def scrape_job_info(url):
    # 2 seconds of "rest" time between each GET request
    time.sleep(2)
    
    # Randomly choose a new fake user agent
    userAgent = ua.random

    try:
        response = requests.get(url, headers=request_headers)
        response.raise_for_status()  # Raise an HTTPError for bad responses (4xx and 5xx)
    
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract job information
        years_of_experience = soup.find('span', string=re.compile("years", re.I)).text.strip()    
        job_description = soup.find('div', id="jobDescription").contents[0].contents[1].text.strip()
        job_type = soup.find('span', string=re.compile("job type", re.I)).parent.contents[1].text.strip()
    
        return {
            'years_of_experience': years_of_experience,
            'job_description': job_description,
            'job_type': job_type
        }
    except requests.RequestException as e:
        print(f"Error accessing {url}: {e}")
        return {
            'years_of_experience': 'N/A',
            'job_description': 'N/A',
            'job_type': 'N/A'
        }

# Apply the scraping function to each URL in the DataFrame
job_info_list = job_url.apply(scrape_job_info)

# Convert the list of dictionaries to a DataFrame and concatenate with the original DataFrame
job_info_df = pd.DataFrame(job_info_list.tolist())
result_df = pd.concat([df, job_info_df], axis=1)

# Display the result DataFrame
print(result_df)
# Out:
#    web-scraper-order                              web-scraper-start-url  \
# 0       1739412261-1  https://www.foundit.in/srp/results?sort=1&limi...
# 1       1739412261-2  https://www.foundit.in/srp/results?sort=1&limi...
# 2       1739412261-3  https://www.foundit.in/srp/results?sort=1&limi...
# 3       1739412261-4  https://www.foundit.in/srp/results?sort=1&limi...
# 4       1739412261-5  https://www.foundit.in/srp/results?sort=1&limi...
# ..               ...                                                ...
# 95     1739412261-96  https://www.foundit.in/srp/results?sort=1&limi...
# 96     1739412261-97  https://www.foundit.in/srp/results?sort=1&limi...
# 97     1739412261-98  https://www.foundit.in/srp/results?sort=1&limi...
# 98     1739412261-99  https://www.foundit.in/srp/results?sort=1&limi...
# 99    1739412261-100  https://www.foundit.in/srp/results?sort=1&limi...
#
#                                             job-title  \
# 0                                  Process Specialist
# 1                 Process Specialist- ServiceNow HRSD
# 2   Application Owner - SAP Financial Accounting &...
# 3   Job Title*- Digital Solution Architect Special...
# 4                             Control M Administrator
# ..                                                ...
# 95                              Audit Compliance Lead
# 96    HCL Technologies | Delivery Compliance| Chennai
# 97                              Sr. Automation Tester
# 98                                 SAP CPI Consultant
# 99                   SAP Central Finance Professional
#
#                                         company  \
# 0                           Infosys BPM Limited
# 1                           Infosys BPM Limited
# 2                            Icici Bank Limited
# 3     NTT DATA Global Delivery Services Limited
# 4   Capgemini Technology Services India Limited
# ..                                          ...
# 95                                Wipro Limited
# 96                     HCL Technologies Limited
# 97                     HCL Technologies Limited
# 98            Tata Consultancy Services Limited
# 99            Tata Consultancy Services Limited
#
#                            locations    job-id  \
# 0                          Bengaluru  34011290
# 1                          Bengaluru  34011276
# 2   Navi Mumbai, Mumbai City, Mumbai  33926390
# 3         Bengaluru, Delhi NCR, Pune  34003469
# 4                          Bengaluru  34003187
# ..                               ...       ...
# 95                         Bengaluru  33471701
# 96                           Chennai  33934492
# 97                         Bengaluru  33935129
# 98     Hyderabad, Chennai, Bengaluru  33882510
# 99     Hyderabad, Bengaluru, Chennai  33935404
#
#                                      edited_job-title  \
# 0                                  Process-Specialist
# 1                  Process-Specialist-ServiceNow-HRSD
# 2   Application-Owner-SAP-Financial-Accounting-Con...
# 3   Job-Title-Digital-Solution-Architect-Specialis...
# 4                             Control-M-Administrator
# ..                                                ...
# 95                              Audit-Compliance-Lead
# 96       HCL-Technologies-Delivery-Compliance-Chennai
# 97                               Sr-Automation-Tester
# 98                                 SAP-CPI-Consultant
# 99                   SAP-Central-Finance-Professional
#
#                                  edited_company  \
# 0                           Infosys-BPM-Limited
# 1                           Infosys-BPM-Limited
# 2                            Icici-Bank-Limited
# 3     NTT-DATA-Global-Delivery-Services-Limited
# 4   Capgemini-Technology-Services-India-Limited
# ..                                          ...
# 95                                Wipro-Limited
# 96                     HCL-Technologies-Limited
# 97                     HCL-Technologies-Limited
# 98            Tata-Consultancy-Services-Limited
# 99            Tata-Consultancy-Services-Limited
#
#                   edited_locations edited_job-id  \
# 0                        Bengaluru      34011290
# 1                        Bengaluru      34011276
# 2   Navi-Mumbai-Mumbai-City-Mumbai      33926390
# 3         Bengaluru-Delhi-NCR-Pune      34003469
# 4                        Bengaluru      34003187
# ..                             ...           ...
# 95                       Bengaluru      33471701
# 96                         Chennai      33934492
# 97                       Bengaluru      33935129
# 98     Hyderabad-Chennai-Bengaluru      33882510
# 99     Hyderabad-Bengaluru-Chennai      33935404
#
#                                               job-url years_of_experience  \
# 0   https://foundit.in/job/Process-Specialist-Info...           2-5 Years
# 1   https://foundit.in/job/Process-Specialist-Serv...           2-4 Years
# 2   https://foundit.in/job/Application-Owner-SAP-F...         12-14 Years
# 3   https://foundit.in/job/Job-Title-Digital-Solut...         10-20 Years
# 4   https://foundit.in/job/Control-M-Administrator...           4-6 Years
# ..                                                ...                 ...
# 95  https://foundit.in/job/Audit-Compliance-Lead-W...           3-8 Years
# 96  https://foundit.in/job/HCL-Technologies-Delive...          9-14 Years
# 97  https://foundit.in/job/Sr-Automation-Tester-HC...          5-10 Years
# 98  https://foundit.in/job/SAP-CPI-Consultant-Tata...           4-9 Years
# 99  https://foundit.in/job/SAP-Central-Finance-Pro...          7-12 Years
#
#                                       job_description       job_type
# 0   Responsibilities\tGood Communication Skill.\tS...  Permanent Job
# 1   Skills & Qualifications:\tExperience:o\t1-3 ye...  Permanent Job
# 2   Essential Services: Role & Location fungibilit...  Permanent Job
# 3   DescriptionWe are looking for a Digital Soluti...  Permanent Job
# 4   Job descriptionBMC Control-M|Primary Skill - C...  Permanent Job
# ..                                                ...            ...
# 95  Managing internal audit activities for technol...  Permanent Job
# 96  Required to have an excellent understanding of...  Permanent Job
# 97  DescriptionWe are seeking a highly skilled Sr....  Permanent Job
# 98  Job descriptionProven experience as an SAP CPI...  Permanent Job
# 99  Job descriptionDesired Competencies (Technical...  Permanent Job
#
# [100 rows x 14 columns]

# %%
result_df.to_csv("foundit-data.csv")
