# %% [markdown]
# # Import the data

# %%
import pandas as pd
df = pd.read_excel("Naukri-all.xlsx")
df
# Out:
#       web-scraper-order                              web-scraper-start-url  \
# 0          1745938777-1  https://www.naukri.com/jobs-in-india-3999?expe...
# 1          1745938779-2  https://www.naukri.com/jobs-in-india-3999?expe...
# 2          1745938781-3  https://www.naukri.com/jobs-in-india-3999?expe...
# 3          1745938784-4  https://www.naukri.com/jobs-in-india-3999?expe...
# 4          1745938785-5  https://www.naukri.com/jobs-in-india-3999?expe...
# ...                 ...                                                ...
# 10239    1746110039-495  https://www.naukri.com/jobs-in-india-0?experie...
# 10240    1746110041-496  https://www.naukri.com/jobs-in-india-0?experie...
# 10241    1746110044-497  https://www.naukri.com/jobs-in-india-0?experie...
# 10242    1746110047-498  https://www.naukri.com/jobs-in-india-0?experie...
# 10243    1746110050-499  https://www.naukri.com/jobs-in-india-0?experie...
#
#                                                    title  \
# 0                                        Product Manager
# 1      Human Resource Generalist (Female Candidate Im...
# 2                            Key Accounts Manager- Noida
# 3                       Sr Executive- Talent Acquisition
# 4                 Voice Process Executive II upto 6.5lpa
# ...                                                  ...
# 10239     Java Full Stack Developer || Infogain || Noida
# 10240                               Deputy Store Manager
# 10241              GCP Java Developer - Immediate Joiner
# 10242                                         Pharmacist
# 10243  Hexaware Hiring_RPA BA_Pan India_Immediate Joiner
#
#                                               title-href  \
# 0      https://www.naukri.com/job-listings-product-ma...
# 1      https://www.naukri.com/job-listings-human-reso...
# 2      https://www.naukri.com/job-listings-key-accoun...
# 3      https://www.naukri.com/job-listings-sr-executi...
# 4      https://www.naukri.com/job-listings-voice-proc...
# ...                                                  ...
# 10239  https://www.naukri.com/job-listings-java-full-...
# 10240  https://www.naukri.com/job-listings-deputy-sto...
# 10241  https://www.naukri.com/job-listings-gcp-java-d...
# 10242  https://www.naukri.com/job-listings-pharmacist...
# 10243  https://www.naukri.com/job-listings-hexaware-h...
#
#                      company work-experience          salary-INR  \
# 0           Somet Consulting     1 - 6 years      5-15 Lacs P.A.
# 1                Sai Educare     2 - 6 years       3-5 Lacs P.A.
# 2           Logis Tech India    5 - 10 years       7-8 Lacs P.A.
# 3                 Connectors    5 - 10 years       5-7 Lacs P.A.
# 4          Talent Organizers     1 - 6 years     3.5-5 Lacs P.A.
# ...                      ...             ...                 ...
# 10239               Infogain     5 - 8 years       Not Disclosed
# 10240        Reliance Retail     4 - 6 years       5-8 Lacs P.A.
# 10241              Capgemini    5 - 10 years       Not Disclosed
# 10242              PharmEasy     0 - 5 years  50,000-3 Lacs P.A.
# 10243  Hexaware Technologies     5 - 8 years       Not Disclosed
#
#                                                locations  \
# 0                            [{"locations":"Ahmedabad"}]
# 1                                [{"locations":"Noida"}]
# 2                                [{"locations":"Noida"}]
# 3                             [{"locations":"Gurugram"}]
# 4      [{"locations":"Gurugram"},{"locations":"Delhi ...
# ...                                                  ...
# 10239  [{"locations":"Pune"},{"locations":"Delhi / NC...
# 10240  [{"locations":"Mumbai"},{"locations":"Pune"},{...
# 10241  [{"locations":"Pune"},{"locations":"Bengaluru"...
# 10242                      [{"locations":"Navi Mumbai"}]
# 10243  [{"locations":"Pune"},{"locations":"Chennai"},...
#
#                                          job-description  \
# 0      -Build user centric products\n-Asses business ...
# 1      End-to-end recruitment and onboarding. Maintai...
# 2      •\tResponsible for operations of warehouse loc...
# 3      Looking for candidate having experience in sal...
# 4      dear candidates,\nwe are hiring for luxury car...
# ...                                                  ...
# 10239  Experience : 5 to 8 yearsJob Location: Noida (...
# 10240  Established in the year 2007, Reliance Brands ...
# 10241  Job Title: GCP Java Developer - Immediate Join...
# 10242  About the company: PharmEasy is a series A fun...
# 10243  We are hiring for Immediate joiners for RPA Bu...
#
#             employment-type                      role-category  \
# 0      Full Time, Permanent    Product Management - Technology
# 1      Full Time, Permanent                      HR Operations
# 2      Full Time, Permanent                    SCM & Logistics
# 3      Full Time, Permanent   Recruitment & Talent Acquisition
# 4      Full Time, Permanent                    Voice / Blended
# ...                     ...                                ...
# 10239  Full Time, Permanent               Software Development
# 10240  Full Time, Permanent            Retail Store Operations
# 10241  Full Time, Permanent                        IT Security
# 10242  Full Time, Permanent     Pharmaceutical & Biotechnology
# 10243  Full Time, Permanent  IT & Information Security - Other
#
#                                                education  \
# 0          [{"education":"UG: Graduation Not Required"}]
# 1      [{"education":"PG: MBA/PGDM in HR/Industrial R...
# 2                     [{"education":"UG: Any Graduate"}]
# 3      [{"education":"PG: MBA/PGDM in HR/Industrial R...
# 4          [{"education":"UG: Graduation Not Required"}]
# ...                                                  ...
# 10239  [{"education":"UG: B.Tech/B.E. in Any Speciali...
# 10240                 [{"education":"UG: Any Graduate"}]
# 10241  [{"education":"UG: Any Graduate, B.Tech/B.E. i...
# 10242         [{"education":"UG: B.Pharma in Pharmacy"}]
# 10243  [{"education":"UG: B.Sc in Computers, B.Tech/B...
#
#                                     preferred-key-skills  \
# 0         [{"preferred-key-skills":"Product Executive"}]
# 1                                                     []
# 2      [{"preferred-key-skills":"Contract Logistics"}...
# 3              [{"preferred-key-skills":"Sales Hiring"}]
# 4      [{"preferred-key-skills":"voice"},{"preferred-...
# ...                                                  ...
# 10239  [{"preferred-key-skills":"java"},{"preferred-k...
# 10240                                                 []
# 10241  [{"preferred-key-skills":"GCP JAVA"},{"preferr...
# 10242                 [{"preferred-key-skills":"sales"}]
# 10243  [{"preferred-key-skills":"RPA Business Analyst...
#
#                                               key-skills
# 0      [{"key-skills":"Product Executive"},{"key-skil...
# 1      [{"key-skills":"Recruitment Life Cycle"},{"key...
# 2      [{"key-skills":"Contract Logistics"},{"key-ski...
# 3      [{"key-skills":"Sales Hiring"},{"key-skills":"...
# 4      [{"key-skills":"voice"},{"key-skills":"Communi...
# ...                                                  ...
# 10239  [{"key-skills":"java"},{"key-skills":"Spring B...
# 10240  [{"key-skills":"software"},{"key-skills":"anal...
# 10241  [{"key-skills":"GCP JAVA"},{"key-skills":"Java...
# 10242  [{"key-skills":"sales"},{"key-skills":"Medical...
# 10243  [{"key-skills":"RPA Business Analyst"},{"key-s...
#
# [10244 rows x 14 columns]

# %% [markdown]
# # Clean the data

# %%
# Drop some irrelevant columns
df.drop(columns=["web-scraper-order", "web-scraper-start-url"], axis=1, inplace=True)

# Rename the 'title-href' column to "url"
df.rename(columns={"title-href": "url"}, inplace=True)

# %%
# Extract value1, value2, value3 for the columns whose value is in the following format:
# "[{"column_name": "value1"}, {"column_name": "value2"}, {"column_name": "value3"}]"
import ast

def clean_education_data(dataframe, column_name):
    """
    Cleans the education data in the specified column of the dataframe.

    Parameters:
    dataframe (pd.DataFrame): The dataframe containing the data.
    column_name (str): The name of the column to clean.

    Returns:
    pd.DataFrame: The dataframe with cleaned education data.
    """
    def clean_entry(entry):
        # Convert string representation of list to actual list
        entry_list = ast.literal_eval(entry)
        
        # Extract and join the education details
        try:
            cleaned_entry = ",".join([item[column_name] for item in entry_list])
        except TypeError:
            cleaned_entry = np.NA
        
        return cleaned_entry

    # Apply the cleaning function to the specified column
    dataframe[column_name] = dataframe[column_name].apply(clean_entry)
    
    return dataframe

df = clean_education_data(df, 'locations')
df = clean_education_data(df, 'education')
df = clean_education_data(df, 'preferred-key-skills')
df = clean_education_data(df, 'key-skills')

# %%
# Drop duplicate rows based on the 'url' column
df.drop_duplicates(subset='url', inplace=True)
df
# Out:
#                                                    title  \
# 0                                        Product Manager
# 1      Human Resource Generalist (Female Candidate Im...
# 2                            Key Accounts Manager- Noida
# 3                       Sr Executive- Talent Acquisition
# 4                 Voice Process Executive II upto 6.5lpa
# ...                                                  ...
# 10239     Java Full Stack Developer || Infogain || Noida
# 10240                               Deputy Store Manager
# 10241              GCP Java Developer - Immediate Joiner
# 10242                                         Pharmacist
# 10243  Hexaware Hiring_RPA BA_Pan India_Immediate Joiner
#
#                                                      url  \
# 0      https://www.naukri.com/job-listings-product-ma...
# 1      https://www.naukri.com/job-listings-human-reso...
# 2      https://www.naukri.com/job-listings-key-accoun...
# 3      https://www.naukri.com/job-listings-sr-executi...
# 4      https://www.naukri.com/job-listings-voice-proc...
# ...                                                  ...
# 10239  https://www.naukri.com/job-listings-java-full-...
# 10240  https://www.naukri.com/job-listings-deputy-sto...
# 10241  https://www.naukri.com/job-listings-gcp-java-d...
# 10242  https://www.naukri.com/job-listings-pharmacist...
# 10243  https://www.naukri.com/job-listings-hexaware-h...
#
#                      company work-experience          salary-INR  \
# 0           Somet Consulting     1 - 6 years      5-15 Lacs P.A.
# 1                Sai Educare     2 - 6 years       3-5 Lacs P.A.
# 2           Logis Tech India    5 - 10 years       7-8 Lacs P.A.
# 3                 Connectors    5 - 10 years       5-7 Lacs P.A.
# 4          Talent Organizers     1 - 6 years     3.5-5 Lacs P.A.
# ...                      ...             ...                 ...
# 10239               Infogain     5 - 8 years       Not Disclosed
# 10240        Reliance Retail     4 - 6 years       5-8 Lacs P.A.
# 10241              Capgemini    5 - 10 years       Not Disclosed
# 10242              PharmEasy     0 - 5 years  50,000-3 Lacs P.A.
# 10243  Hexaware Technologies     5 - 8 years       Not Disclosed
#
#                                  locations  \
# 0                                Ahmedabad
# 1                                    Noida
# 2                                    Noida
# 3                                 Gurugram
# 4                     Gurugram,Delhi / NCR
# ...                                    ...
# 10239  Pune,Delhi / NCR,Mumbai (All Areas)
# 10240                    Mumbai,Pune,Surat
# 10241    Pune,Bengaluru,Mumbai (All Areas)
# 10242                          Navi Mumbai
# 10243      Pune,Chennai,Mumbai (All Areas)
#
#                                          job-description  \
# 0      -Build user centric products\n-Asses business ...
# 1      End-to-end recruitment and onboarding. Maintai...
# 2      •\tResponsible for operations of warehouse loc...
# 3      Looking for candidate having experience in sal...
# 4      dear candidates,\nwe are hiring for luxury car...
# ...                                                  ...
# 10239  Experience : 5 to 8 yearsJob Location: Noida (...
# 10240  Established in the year 2007, Reliance Brands ...
# 10241  Job Title: GCP Java Developer - Immediate Join...
# 10242  About the company: PharmEasy is a series A fun...
# 10243  We are hiring for Immediate joiners for RPA Bu...
#
#             employment-type                      role-category  \
# 0      Full Time, Permanent    Product Management - Technology
# 1      Full Time, Permanent                      HR Operations
# 2      Full Time, Permanent                    SCM & Logistics
# 3      Full Time, Permanent   Recruitment & Talent Acquisition
# 4      Full Time, Permanent                    Voice / Blended
# ...                     ...                                ...
# 10239  Full Time, Permanent               Software Development
# 10240  Full Time, Permanent            Retail Store Operations
# 10241  Full Time, Permanent                        IT Security
# 10242  Full Time, Permanent     Pharmaceutical & Biotechnology
# 10243  Full Time, Permanent  IT & Information Security - Other
#
#                                                education  \
# 0                            UG: Graduation Not Required
# 1                PG: MBA/PGDM in HR/Industrial Relations
# 2                                       UG: Any Graduate
# 3                PG: MBA/PGDM in HR/Industrial Relations
# 4                            UG: Graduation Not Required
# ...                                                  ...
# 10239  UG: B.Tech/B.E. in Any Specialization,PG: M.Te...
# 10240                                   UG: Any Graduate
# 10241  UG: Any Graduate, B.Tech/B.E. in Any Specializ...
# 10242                           UG: B.Pharma in Pharmacy
# 10243  UG: B.Sc in Computers, B.Tech/B.E. in Computer...
#
#                                     preferred-key-skills  \
# 0                                      Product Executive
# 1
# 2      Contract Logistics,SAP,Warehouse Management,Wa...
# 3                                           Sales Hiring
# 4                 voice,Communication Skills,experienced
# ...                                                  ...
# 10239                             java,Spring Boot,react
# 10240
# 10241            GCP JAVA,Java Spring Boot,Microservices
# 10242                                              sales
# 10243      RPA Business Analyst,RPA BA,Business Analysis
#
#                                               key-skills
# 0      Product Executive,Banking Process,Lending,Fint...
# 1              Recruitment Life Cycle,Payroll Processing
# 2      Contract Logistics,SAP,Warehouse Management,Wa...
# 3      Sales Hiring,Sales HR,Sales Recruitment,sales ...
# 4      voice,Communication Skills,experienced,bpo,cus...
# ...                                                  ...
# 10239  java,Spring Boot,react,React.Js,core java,Micr...
# 10240  software,analytical,po system,interpersonal sk...
# 10241        GCP JAVA,Java Spring Boot,Microservices,GCP
# 10242           sales,Medical Sales,Prescription reading
# 10243  RPA Business Analyst,RPA BA,Business Analysis,...
#
# [10244 rows x 12 columns]

# %%
# Filter the "employment-type" column
employment_type_values = ['Full Time, Permanent','Part Time, Permanent','Full Time, Permanent','Part Time, Permanent',
                   'Full Time, Temporary/Contractual','Part Time, Freelance/Homebased','Part Time, Temporary/Contractual',
                   'Full Time, Freelance/Homebased']
df = df[df['employment-type'].isna() | df['employment-type'].isin(employment_type_values)]
df
# Out:
#                                                    title  \
# 0                                        Product Manager
# 1      Human Resource Generalist (Female Candidate Im...
# 2                            Key Accounts Manager- Noida
# 3                       Sr Executive- Talent Acquisition
# 4                 Voice Process Executive II upto 6.5lpa
# ...                                                  ...
# 10239     Java Full Stack Developer || Infogain || Noida
# 10240                               Deputy Store Manager
# 10241              GCP Java Developer - Immediate Joiner
# 10242                                         Pharmacist
# 10243  Hexaware Hiring_RPA BA_Pan India_Immediate Joiner
#
#                                                      url  \
# 0      https://www.naukri.com/job-listings-product-ma...
# 1      https://www.naukri.com/job-listings-human-reso...
# 2      https://www.naukri.com/job-listings-key-accoun...
# 3      https://www.naukri.com/job-listings-sr-executi...
# 4      https://www.naukri.com/job-listings-voice-proc...
# ...                                                  ...
# 10239  https://www.naukri.com/job-listings-java-full-...
# 10240  https://www.naukri.com/job-listings-deputy-sto...
# 10241  https://www.naukri.com/job-listings-gcp-java-d...
# 10242  https://www.naukri.com/job-listings-pharmacist...
# 10243  https://www.naukri.com/job-listings-hexaware-h...
#
#                      company work-experience          salary-INR  \
# 0           Somet Consulting     1 - 6 years      5-15 Lacs P.A.
# 1                Sai Educare     2 - 6 years       3-5 Lacs P.A.
# 2           Logis Tech India    5 - 10 years       7-8 Lacs P.A.
# 3                 Connectors    5 - 10 years       5-7 Lacs P.A.
# 4          Talent Organizers     1 - 6 years     3.5-5 Lacs P.A.
# ...                      ...             ...                 ...
# 10239               Infogain     5 - 8 years       Not Disclosed
# 10240        Reliance Retail     4 - 6 years       5-8 Lacs P.A.
# 10241              Capgemini    5 - 10 years       Not Disclosed
# 10242              PharmEasy     0 - 5 years  50,000-3 Lacs P.A.
# 10243  Hexaware Technologies     5 - 8 years       Not Disclosed
#
#                                  locations  \
# 0                                Ahmedabad
# 1                                    Noida
# 2                                    Noida
# 3                                 Gurugram
# 4                     Gurugram,Delhi / NCR
# ...                                    ...
# 10239  Pune,Delhi / NCR,Mumbai (All Areas)
# 10240                    Mumbai,Pune,Surat
# 10241    Pune,Bengaluru,Mumbai (All Areas)
# 10242                          Navi Mumbai
# 10243      Pune,Chennai,Mumbai (All Areas)
#
#                                          job-description  \
# 0      -Build user centric products\n-Asses business ...
# 1      End-to-end recruitment and onboarding. Maintai...
# 2      •\tResponsible for operations of warehouse loc...
# 3      Looking for candidate having experience in sal...
# 4      dear candidates,\nwe are hiring for luxury car...
# ...                                                  ...
# 10239  Experience : 5 to 8 yearsJob Location: Noida (...
# 10240  Established in the year 2007, Reliance Brands ...
# 10241  Job Title: GCP Java Developer - Immediate Join...
# 10242  About the company: PharmEasy is a series A fun...
# 10243  We are hiring for Immediate joiners for RPA Bu...
#
#             employment-type                      role-category  \
# 0      Full Time, Permanent    Product Management - Technology
# 1      Full Time, Permanent                      HR Operations
# 2      Full Time, Permanent                    SCM & Logistics
# 3      Full Time, Permanent   Recruitment & Talent Acquisition
# 4      Full Time, Permanent                    Voice / Blended
# ...                     ...                                ...
# 10239  Full Time, Permanent               Software Development
# 10240  Full Time, Permanent            Retail Store Operations
# 10241  Full Time, Permanent                        IT Security
# 10242  Full Time, Permanent     Pharmaceutical & Biotechnology
# 10243  Full Time, Permanent  IT & Information Security - Other
#
#                                                education  \
# 0                            UG: Graduation Not Required
# 1                PG: MBA/PGDM in HR/Industrial Relations
# 2                                       UG: Any Graduate
# 3                PG: MBA/PGDM in HR/Industrial Relations
# 4                            UG: Graduation Not Required
# ...                                                  ...
# 10239  UG: B.Tech/B.E. in Any Specialization,PG: M.Te...
# 10240                                   UG: Any Graduate
# 10241  UG: Any Graduate, B.Tech/B.E. in Any Specializ...
# 10242                           UG: B.Pharma in Pharmacy
# 10243  UG: B.Sc in Computers, B.Tech/B.E. in Computer...
#
#                                     preferred-key-skills  \
# 0                                      Product Executive
# 1
# 2      Contract Logistics,SAP,Warehouse Management,Wa...
# 3                                           Sales Hiring
# 4                 voice,Communication Skills,experienced
# ...                                                  ...
# 10239                             java,Spring Boot,react
# 10240
# 10241            GCP JAVA,Java Spring Boot,Microservices
# 10242                                              sales
# 10243      RPA Business Analyst,RPA BA,Business Analysis
#
#                                               key-skills
# 0      Product Executive,Banking Process,Lending,Fint...
# 1              Recruitment Life Cycle,Payroll Processing
# 2      Contract Logistics,SAP,Warehouse Management,Wa...
# 3      Sales Hiring,Sales HR,Sales Recruitment,sales ...
# 4      voice,Communication Skills,experienced,bpo,cus...
# ...                                                  ...
# 10239  java,Spring Boot,react,React.Js,core java,Micr...
# 10240  software,analytical,po system,interpersonal sk...
# 10241        GCP JAVA,Java Spring Boot,Microservices,GCP
# 10242           sales,Medical Sales,Prescription reading
# 10243  RPA Business Analyst,RPA BA,Business Analysis,...
#
# [10167 rows x 12 columns]

# %% [markdown]
# # Visualize the dataset

# %% [markdown]
# ## Make histograms of some columns

# %%
import matplotlib.pyplot as plt

# Created by Copilot
# A method that draw histograms from data in a specific column
def draw_histogram(dataframe, column_name):
    """
    Draws a histogram for the specified column in the dataframe.

    Parameters:
    dataframe (pd.DataFrame): The dataframe containing the data.
    column_name (str): The name of the column to plot.

    Returns:
    None
    """
    if column_name in dataframe.columns:
        plt.figure(figsize=(10, 6))
        dataframe[column_name].hist(bins=30, edgecolor='black')
        plt.title(f'Histogram of {column_name}')
        plt.xlabel(column_name)
        plt.ylabel('Frequency')
        plt.xticks(rotation=90)  # Rotate x-axis labels vertically
        plt.grid(False)
        plt.show()
    else:
        print(f"Column '{column_name}' does not exist in the dataframe.")

draw_histogram(df, 'company')
draw_histogram(df, 'salary-INR')
draw_histogram(df, 'locations')
draw_histogram(df, 'employment-type')

# %% [markdown]
# ## View missing data

# %%
# An array that contain the indices of rows that have any NA value
missing_data_rows = df[df.isna().any(axis=1) | (df == '').any(axis=1)]
missing_data_rows = missing_data_rows[missing_data_rows == True].index.tolist()

print("Rows with missing data: {}".format(missing_data_rows))
print("Number of rows with missing data: {}".format(len(missing_data_rows)))
# Out:
# Rows with missing data: [1, 28, 46, 47, 101, 103, 116, 128, 168, 184, 193, 199, 210, 255, 290, 300, 323, 329, 359, 369, 371, 389, 398, 418, 456, 457, 479, 484, 504, 668, 671, 692, 740, 755, 768, 770, 871, 923, 930, 988, 993, 1019, 1089, 1128, 1164, 1209, 1263, 1271, 1290, 1291, 1302, 1303, 1334, 1356, 1358, 1401, 1419, 1424, 1443, 1452, 1460, 1550, 1551, 1620, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1648, 1649, 1650, 1651, 1652, 1653, 1654, 1655, 1656, 1657, 1658, 1659, 1662, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1735, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1754, 1821, 1860, 1885, 1894, 1896, 1904, 1937, 1939, 1940, 1966, 2009, 2010, 2027, 2028, 2029, 2032, 2041, 2044, 2049, 2072, 2080, 2094, 2103, 2125, 2147, 2150, 2159, 2165, 2186, 2210, 2219, 2222, 2231, 2238, 2239, 2281, 2282, 2292, 2330, 2349, 2353, 2365, 2370, 2376, 2391, 2432, 2440, 2441, 2442, 2443, 2444, 2445, 2446, 2447, 2448, 2449, 2450, 2451, 2452, 2453, 2454, 2455, 2456, 2457, 2458, 2459, 2460, 2461, 2462, 2463, 2464, 2465, 2466, 2467, 2468, 2469, 2470, 2471, 2472, 2473, 2475, 2476, 2477, 2478, 2479, 2480, 2481, 2482, 2483, 2484, 2485, 2486, 2487, 2488, 2489, 2490, 2491, 2492, 2494, 2495, 2496, 2497, 2498, 2499, 2500, 2501, 2502, 2503, 2504, 2505, 2506, 2507, 2508, 2509, 2510, 2511, 2512, 2513, 2514, 2515, 2516, 2517, 2518, 2519, 2520, 2569, 2586, 2595, 2606, 2624, 2657, 2659, 2664, 2682, 2700, 2708, 2722, 2756, 2760, 2761, 2762, 2763, 2764, 2765, 2766, 2767, 2768, 2769, 2770, 2771, 2772, 2773, 2774, 2775, 2776, 2777, 2778, 2779, 2780, 2781, 2782, 2783, 2784, 2785, 2786, 2787, 2788, 2789, 2793, 2794, 2795, 2797, 2798, 2799, 2800, 2801, 2802, 2803, 2804, 2805, 2806, 2807, 2808, 2809, 2810, 2811, 2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 2820, 2821, 2822, 2823, 2824, 2825, 2826, 2827, 2828, 2829, 2830, 2831, 2832, 2833, 2834, 2835, 2836, 2837, 2838, 2839, 2840, 2841, 2842, 2843, 2844, 2845, 2846, 2847, 2848, 2849, 2850, 2851, 2852, 2853, 2854, 2855, 2856, 2857, 2858, 2859, 2860, 2861, 2862, 2863, 2864, 2865, 2866, 2867, 2868, 2869, 2870, 2871, 2872, 2873, 2874, 2875, 2876, 2877, 2878, 2879, 2880, 2881, 2882, 2883, 2884, 2885, 2886, 2887, 2888, 2889, 2890, 2891, 2892, 2893, 2894, 2895, 2896, 2897, 2898, 2899, 2900, 2901, 2902, 2903, 2904, 2905, 2906, 2907, 2908, 2909, 2910, 2911, 2912, 2914, 2915, 2916, 2917, 2918, 2919, 2971, 2983, 3048, 3084, 3102, 3104, 3146, 3192, 3198, 3221, 3222, 3223, 3224, 3225, 3226, 3227, 3228, 3229, 3230, 3231, 3232, 3233, 3234, 3235, 3236, 3237, 3238, 3239, 3240, 3241, 3242, 3243, 3244, 3245, 3246, 3247, 3249, 3250, 3252, 3253, 3254, 3255, 3256, 3257, 3258, 3259, 3260, 3262, 3263, 3264, 3265, 3266, 3267, 3268, 3269, 3270, 3271, 3272, 3273, 3274, 3275, 3276, 3277, 3278, 3279, 3280, 3281, 3282, 3283, 3284, 3285, 3286, 3287, 3288, 3289, 3290, 3291, 3292, 3293, 3294, 3295, 3296, 3297, 3298, 3299, 3300, 3301, 3302, 3303, 3304, 3305, 3306, 3307, 3308, 3309, 3310, 3311, 3312, 3313, 3314, 3315, 3316, 3317, 3318, 3319, 3320, 3321, 3322, 3323, 3324, 3325, 3326, 3327, 3328, 3329, 3330, 3331, 3332, 3333, 3334, 3335, 3336, 3337, 3338, 3339, 3340, 3341, 3342, 3343, 3344, 3345, 3346, 3347, 3348, 3349, 3350, 3351, 3352, 3353, 3354, 3355, 3356, 3357, 3358, 3359, 3360, 3361, 3362, 3363, 3364, 3365, 3366, 3367, 3368, 3369, 3370, 3371, 3372, 3373, 3374, 3375, 3376, 3377, 3378, 3379, 3380, 3381, 3382, 3383, 3384, 3385, 3386, 3387, 3388, 3389, 3390, 3391, 3392, 3393, 3394, 3395, 3396, 3397, 3398, 3399, 3400, 3401, 3402, 3403, 3404, 3405, 3406, 3407, 3408, 3409, 3410, 3411, 3412, 3447, 3455, 3476, 3478, 3491, 3492, 3527, 3539, 3551, 3565, 3568, 3574, 3577, 3590, 3611, 3612, 3624, 3629, 3630, 3631, 3632, 3633, 3634, 3635, 3636, 3637, 3638, 3639, 3640, 3641, 3642, 3643, 3644, 3645, 3646, 3647, 3648, 3649, 3650, 3651, 3652, 3653, 3654, 3655, 3656, 3657, 3658, 3659, 3660, 3661, 3662, 3663, 3664, 3665, 3667, 3668, 3669, 3670, 3671, 3672, 3673, 3674, 3675, 3676, 3 ...
# Number of rows with missing data: 2573

# %%
# An array that contain the columns that have any NA value
missing_data_columns = df.columns[df.isna().any() | (df == '').any()]

# Print out those columns' name
print("Columns with missing data: {}".format(missing_data_columns.values))
# Out:
# Columns with missing data: ['company' 'work-experience' 'salary-INR' 'locations' 'job-description'
#  'employment-type' 'role-category' 'education' 'preferred-key-skills'
#  'key-skills']

# %% [markdown]
# # Append the cleaned data to the Excel file

# %%
# Add the dataframe to a new sheet
with pd.ExcelWriter("Naukri-all.xlsx", engine='openpyxl', mode='a') as writer:
    df.to_excel(writer, sheet_name="Cleaned data", index=False)
